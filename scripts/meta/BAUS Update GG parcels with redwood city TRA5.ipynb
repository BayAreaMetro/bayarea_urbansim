# %% [markdown]
# # Update GG file to add additional parcels with GG / TRA_3 status near Redwood City Ferry Terminal
#
# We have a list of parcels from Mark:
# * we load parcel classes
# * filter on the new subset
# * update the relevant columns.
# * check that no new GG categories are created (which would impact zoningmods)
# * write updated file to disk

# %%
import pathlib
import pandas as pd
import geopandas as gpd
import os

# %%
HOME_DIR = pathlib.Path.home()
# in my (AO) case, M:\urban_modeling is mounted to /Volumes/Data/Models/urban_modeling
m_drive = M_DRIVE = pathlib.Path(
    "/Volumes/Data/Models") if os.name != "nt" else "M:/"

BOX_DIR = HOME_DIR / 'Library/CloudStorage/Box-Box'
HOME_DIR
# Out:
# PosixPath('/Users/aolsen')

# %%
PARCEL_GEOS_FILE_FBP_FEB25 = m_drive / \
    'urban_modeling/baus/BAUS Inputs/basis_inputs/crosswalks/fbp_urbansim_parcel_classes_ot50pct_feb25_2025.csv'

PARCEL_GEOS_FILE_FBP_FEB14 = m_drive / \
    'urban_modeling/baus/BAUS Inputs/basis_inputs/crosswalks/fbp_urbansim_parcel_classes_ot50pct_feb14_2025.csv'

PARCEL_GEOS_FILE_FBP_FEB25_rwc = m_drive / \
    'urban_modeling/baus/BAUS Inputs/basis_inputs/crosswalks/fbp_urbansim_parcel_classes_ot50pct_feb25_rwc_update_2025.csv'

# %%
# convenience function for adding zoningmodcat as a function of the relevant components

def add_zoningmodcat(gg):

    parcels_geography_fbp_cols = ["gg_id", "exd_id", "pda_id",
                                  "tra_id", "hra_id",  "dis_id", "ppa_id", "ugb_id"]

    parcels_geographies_FBP[parcels_geography_fbp_cols] = parcels_geographies_FBP[parcels_geography_fbp_cols].astype(str).map(lambda x: x.lower()).fillna(
        'Remainder')

    zoning_mod_cols = ["gg_id", "exd_id",
                       "tra_id", "hra_id", "ppa_id", "ugb_id"]
    parcels_geographies_FBP["zoningmodcat"] = (
        parcels_geographies_FBP[zoning_mod_cols]
        .astype(str)
        .apply(lambda x: "".join(x), axis=1)
        .str.lower()
    )
    return parcels_geographies_FBP

# %% [markdown]
# # Load data
#
# ## Parcel classes

# %%
parcels_geographies_FBP = pd.read_csv(
    PARCEL_GEOS_FILE_FBP_FEB25)

parcels_geographies_FBP = parcels_geographies_FBP.set_index('parcel_id')

# %%
feb25 = add_zoningmodcat(PARCEL_GEOS_FILE_FBP_FEB25)

# %%
feb25.head()
# Out:
#           gg_id                                   pda_id ppa_id tra_id hra_id  \
# parcel_id
# 22.0         gg                   oakland - west oakland    nan    nan    nan
# 58.0         gg                                      nan    ppa    nan    nan
# 128.0        gg                   oakland - west oakland    nan    nan    nan
# 217.0        gg  oakland - downtown & jack london square    nan  tra_4    nan
# 358.0        gg  oakland - downtown & jack london square    nan  tra_4    nan
#
#           ugb_id tpp_id dis_id exp2020_id exsfd_id exd_id         zoningmodcat
# parcel_id
# 22.0         ugb   brt3    nan         in      NaN    nan    ggnannannannanugb
# 58.0         ugb    NaN    nan         in      NaN    nan    ggnannannanppaugb
# 128.0        ugb  bart1    nan         in      NaN    nan    ggnannannannanugb
# 217.0        ugb   brt1    nan         in      NaN    nan  ggnantra_4nannanugb
# 358.0        ugb   lrt2    dis         in      NaN    nan  ggnantra_4nannanugb

# %% [markdown]
# ## Redwood City updates

# %%
updates_path = m_drive / \
    'urban_modeling/baus/BAUS Inputs/basis_inputs/crosswalks/RWC_Parcels_to_add_to_tra5_gg.csv'
updates = pd.read_csv(updates_path)
print('Parcels in update: ',len(updates))
updates.head()
# Out:
# Parcels in update:  16
#    OBJECTID *  Shape *  parcel_id     county  jurisdiction     acres  \
# 0           1  Polygon    1173302  San Mateo  redwood_city  4.439077
# 1           2  Polygon    1173388  San Mateo  redwood_city  1.995135
# 2           3  Polygon    1173382  San Mateo  redwood_city  3.139200
# 3           5  Polygon    1173373  San Mateo  redwood_city  4.367664
# 4           7  Polygon    1173383  San Mateo  redwood_city  2.733019
#
#             x          y  is_multipolygon  in_growth_geography_designation  \
# 0 -122.212159  37.504586                0                                1
# 1 -122.201318  37.510768                0                                1
# 2 -122.204709  37.511279                0                                1
# 3 -122.203297  37.513483                0                                1
# 4 -122.205753  37.510605                0                                1
#
#   in_high_resource_area in_priority_dev_area in_priority_prod_area  \
# 0                <Null>               <Null>                <Null>
# 1                <Null>               <Null>                <Null>
# 2                <Null>               <Null>                <Null>
# 3                <Null>               <Null>                <Null>
# 4                <Null>               <Null>                <Null>
#
#   in_transit_rich_area  in_urban_growth_boundaries_area  Shape_Length  \
# 0                 tra5                                1    758.417815
# 1                 tra5                                1    367.107992
# 2                 tra5                                1    478.591783
# 3                 tra5                                1    611.947558
# 4                 tra5                                1    434.422991
#
#      Shape_Area
# 0  17964.334570
# 1   8074.037571
# 2  12703.911990
# 3  17675.335420
# 4  11060.153470

# %%
## check gg / tra status for the updates parcels before the update
# note zoningmodcat is nannannannannanugb

feb25.loc[updates.parcel_id]
# Out:
#           gg_id pda_id ppa_id tra_id hra_id ugb_id tpp_id dis_id exp2020_id  \
# parcel_id
# 1173302.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173388.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173382.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173373.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173383.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173303.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173296.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173384.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173385.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173386.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173376.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173387.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173305.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173377.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173389.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
# 1173300.0   nan    nan    nan    nan    nan    ugb    NaN    dis         in
#
#           exsfd_id exd_id        zoningmodcat
# parcel_id
# 1173302.0      NaN    nan  nannannannannanugb
# 1173388.0      NaN    nan  nannannannannanugb
# 1173382.0      NaN    nan  nannannannannanugb
# 1173373.0      NaN    nan  nannannannannanugb
# 1173383.0      NaN    nan  nannannannannanugb
# 1173303.0      NaN    nan  nannannannannanugb
# 1173296.0      NaN    nan  nannannannannanugb
# 1173384.0      NaN    nan  nannannannannanugb
# 1173385.0      NaN    nan  nannannannannanugb
# 1173386.0      NaN    nan  nannannannannanugb
# 1173376.0      NaN    nan  nannannannannanugb
# 1173387.0      NaN    nan  nannannannannanugb
# 1173305.0      NaN    nan  nannannannannanugb
# 1173377.0      NaN    nan  nannannannannanugb
# 1173389.0      NaN    nan  nannannannannanugb
# 1173300.0      NaN    nan  nannannannannanugb

# %% [markdown]
# # Apply updates to the parcel set - they should be tra_5 and gg

# %%
# apply updates

parcels_geographies_FBP.loc[updates.parcel_id,
                            ['gg_id', 'tra_id']] = ['gg', 'tra_5']

# %%
parcels_geographies_FBP.loc[updates.parcel_id,['gg_id','tra_id']]
# Out:
#           gg_id tra_id
# parcel_id
# 1173302.0    gg  tra_5
# 1173388.0    gg  tra_5
# 1173382.0    gg  tra_5
# 1173373.0    gg  tra_5
# 1173383.0    gg  tra_5
# 1173303.0    gg  tra_5
# 1173296.0    gg  tra_5
# 1173384.0    gg  tra_5
# 1173385.0    gg  tra_5
# 1173386.0    gg  tra_5
# 1173376.0    gg  tra_5
# 1173387.0    gg  tra_5
# 1173305.0    gg  tra_5
# 1173377.0    gg  tra_5
# 1173389.0    gg  tra_5
# 1173300.0    gg  tra_5

# %% [markdown]
# # Check what the zoningmodcat would be given the updates

# %%
# reapply zoningmodcat based on updated components
feb25_rc = add_zoningmodcat(PARCEL_GEOS_FILE_FBP_FEB25)

# %%
feb25_rc.loc[updates.parcel_id]
# Out:
#           gg_id pda_id ppa_id tra_id hra_id ugb_id tpp_id dis_id exp2020_id  \
# parcel_id
# 1173302.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173388.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173382.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173373.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173383.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173303.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173296.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173384.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173385.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173386.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173376.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173387.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173305.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173377.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173389.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173300.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
#
#           exsfd_id exd_id         zoningmodcat
# parcel_id
# 1173302.0      NaN    nan  ggnantra_5nannanugb
# 1173388.0      NaN    nan  ggnantra_5nannanugb
# 1173382.0      NaN    nan  ggnantra_5nannanugb
# 1173373.0      NaN    nan  ggnantra_5nannanugb
# 1173383.0      NaN    nan  ggnantra_5nannanugb
# 1173303.0      NaN    nan  ggnantra_5nannanugb
# 1173296.0      NaN    nan  ggnantra_5nannanugb
# 1173384.0      NaN    nan  ggnantra_5nannanugb
# 1173385.0      NaN    nan  ggnantra_5nannanugb
# 1173386.0      NaN    nan  ggnantra_5nannanugb
# 1173376.0      NaN    nan  ggnantra_5nannanugb
# 1173387.0      NaN    nan  ggnantra_5nannanugb
# 1173305.0      NaN    nan  ggnantra_5nannanugb
# 1173377.0      NaN    nan  ggnantra_5nannanugb
# 1173389.0      NaN    nan  ggnantra_5nannanugb
# 1173300.0      NaN    nan  ggnantra_5nannanugb

# %%
# this is the new zoningmodcat

derived_zoningmodcat = feb25_rc.loc[updates.parcel_id].zoningmodcat.unique()
derived_zoningmodcat
# Out:
# array(['ggnantra_5nannanugb'], dtype=object)

# %%
# checking this zoningmodcat exists elsewhere in the file - checks out

parcels_geographies_FBP[parcels_geographies_FBP.zoningmodcat.isin(derived_zoningmodcat)].groupby('pda_id').size()
# Out:
# pda_id
# alameda - naval air station                                                                       31
# alameda - northern waterfront                                                                    133
# berkeley - southside/telegraph avenue                                                            110
# brentwood - brentwood transit village                                                             40
# campbell - central campbell                                                                       17
# campbell - hamilton avenue specific plan area                                                      9
# concord - downtown                                                                                78
# cotati - downtown and cotati depot                                                                23
# daly city - bayshore                                                                              65
# daly city - mission boulevard                                                                      6
# emeryville - mixed-use core                                                                      102
# fairfield - fairfield-vacaville train station                                                     38
# fairfield - heart of fairfield                                                                   165
# gilroy - downtown gilroy                                                                         367
# healdsburg - healdsburg smart station                                                            201
# livermore - downtown                                                                              34
# livermore - mcgrath southfront pda                                                                45
# martinez - downtown                                                                              281
# morgan hill - downtown morgan hill                                                               235
# mountain view - el camino real                                                                    17
# nan                                                                                             5480
# oakland - coliseum bay area rapid transit station area                                            15
# oakland - downtown & jack london square                                                            2
# oakland - west oakland                                                                             1
# petaluma - corona                                                                                 55
# petaluma - lakeville                                                                               7
# pleasant hill - buskirk avenue corridor                                                           69
# pleasant hill - diablo valley college                                                             19
# richmond - richmond: central richmond & 23rd street corridor (a)                                 367
# richmond - richmond: central richmond & 23rd street corridor (b)                                  33
# richmond - richmond: hilltop                                                                       8
# richmond - richmond: south richmond                                                               63
# rohnert park - central rohnert park                                                               66
# san francisco - downtown/van ness/northeast neighborhoods                                         15
# san francisco - treasure island/yerba buena island                                                32
# san jose - bascom tod corridor                                                                     8
# san jose - communications hill                                                                   106
# san jose - cottle transit village (hitachi)                                                        2
# san jose - east santa clara/alum rock corridor                                                     4
# san jose - greater downtown                                                                       11
# san jose - santa clara valley transportation authority city cores, corridors & station areas      32
# san jose - west san carlos and southwest expressway corridors                                     92
# san pablo - san pablo avenue & 23rd street corridors                                              15
# san rafael - northgate pda                                                                        17
# san rafael - south east san rafael canal pda                                                       2
# santa clara - el camino real focus area                                                           74
# santa clara - santa clara station focus area                                                      16
# santa rosa - downtown station area                                                                25
# santa rosa - north santa rosa station                                                            139
# south san francisco - downtown                                                                    27
# suisun city - downtown & waterfront                                                              155
# sunnyvale - east sunnyvale                                                                        67
# unincorporated alameda - hesperian boulevard                                                     215
# unincorporated marin - cal park                                                                    1
# unincorporated sonoma - airport industrial specific plan                                         107
# vallejo - mare island pda                                                                          1
# windsor - station area/downtown specific plan area                                               177
# dtype: int64

# %% [markdown]
# # Write updated parcel classes table to disk

# %%
parcels_geographies_FBP.to_csv(PARCEL_GEOS_FILE_FBP_FEB25_rwc)

# %%
parcels_geographies_FBP.loc[updates.parcel_id]
# Out:
#           gg_id pda_id ppa_id tra_id hra_id ugb_id tpp_id dis_id exp2020_id  \
# parcel_id
# 1173302.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173388.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173382.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173373.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173383.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173303.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173296.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173384.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173385.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173386.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173376.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173387.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173305.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173377.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173389.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
# 1173300.0    gg    nan    nan  tra_5    nan    ugb    NaN    dis         in
#
#           exsfd_id exd_id         zoningmodcat
# parcel_id
# 1173302.0      NaN    nan  ggnantra_5nannanugb
# 1173388.0      NaN    nan  ggnantra_5nannanugb
# 1173382.0      NaN    nan  ggnantra_5nannanugb
# 1173373.0      NaN    nan  ggnantra_5nannanugb
# 1173383.0      NaN    nan  ggnantra_5nannanugb
# 1173303.0      NaN    nan  ggnantra_5nannanugb
# 1173296.0      NaN    nan  ggnantra_5nannanugb
# 1173384.0      NaN    nan  ggnantra_5nannanugb
# 1173385.0      NaN    nan  ggnantra_5nannanugb
# 1173386.0      NaN    nan  ggnantra_5nannanugb
# 1173376.0      NaN    nan  ggnantra_5nannanugb
# 1173387.0      NaN    nan  ggnantra_5nannanugb
# 1173305.0      NaN    nan  ggnantra_5nannanugb
# 1173377.0      NaN    nan  ggnantra_5nannanugb
# 1173389.0      NaN    nan  ggnantra_5nannanugb
# 1173300.0      NaN    nan  ggnantra_5nannanugb
