# %%
import pandas as pd
import geopandas as gpd 
import numpy as np 
import fiona
import os

# %%
bayareafips = {
    "06001": "Alameda",
    "06013": "Contra Costa",
    "06041": "Marin",
    "06055": "Napa",
    "06075": "San Francisco",
    "06081": "San Mateo",
    "06085": "Santa Clara",
    "06097": "Sonoma",
    "06095": "Solano",
}

PARCEL_TAZ_CROSSWALK_FILE = r"M:\urban_modeling\baus\BAUS Inputs\basis_inputs\crosswalks\2020_08_17_parcel_to_taz1454sub.csv"
parcel_taz_crosswalk_df = pd.read_csv(PARCEL_TAZ_CROSSWALK_FILE, usecols=['PARCEL_ID', 'ZONE_ID', 'manual_county'])
parcel_taz_crosswalk_df.columns = parcel_taz_crosswalk_df.columns.str.lower()
parcel_taz_crosswalk_df["county"] = parcel_taz_crosswalk_df['manual_county'].map(
    lambda x: f"06{x:03d}"
).map(bayareafips)
del parcel_taz_crosswalk_df['manual_county']
print(f"  Read {len(parcel_taz_crosswalk_df):,} rows from crosswalk {PARCEL_TAZ_CROSSWALK_FILE}")
print(f"  parcel_taz_crosswalk_df.head():\n{parcel_taz_crosswalk_df.head()}")

TAZ_SD_CROSSWALK_FILE = r"M:\urban_modeling\baus\BAUS Inputs\basis_inputs\crosswalks\taz_geography.csv"
taz_sd_crosswalk_df = pd.read_csv(TAZ_SD_CROSSWALK_FILE, usecols=['zone', 'superdistrict'])
taz_sd_crosswalk_df.rename(columns={"zone": "zone_id"}, inplace=True)
print(f"  Read {len(taz_sd_crosswalk_df):,} rows from crosswalk {TAZ_SD_CROSSWALK_FILE}")
print(f"  taz_sd_crosswalk_df.head():\n{taz_sd_crosswalk_df.head()}")

parcel_taz_sd_crosswalk_df = pd.merge(
    left     = parcel_taz_crosswalk_df,
    right    = taz_sd_crosswalk_df,
    on       = 'zone_id',
    how      = 'left',
    validate = 'many_to_one'
)
display(parcel_taz_sd_crosswalk_df.head())
# Out:
#   Read 1,956,208 rows from crosswalk M:\urban_modeling\baus\BAUS Inputs\basis_inputs\crosswalks\2020_08_17_parcel_to_taz1454sub.csv
#   parcel_taz_crosswalk_df.head():
#    parcel_id  zone_id   county
# 0     229116      725  Alameda
# 1     244166      715  Alameda
# 2     202378      820  Alameda
# 3    2004420     1401   Sonoma
# 4     340332      763  Alameda
#   Read 1,454 rows from crosswalk M:\urban_modeling\baus\BAUS Inputs\basis_inputs\crosswalks\taz_geography.csv
#   taz_sd_crosswalk_df.head():
#    zone_id  superdistrict
# 0        1              1
# 1        2              1
# 2        3              1
# 3        4              1
# 4        5              1
#    parcel_id  zone_id   county  superdistrict
# 0     229116      725  Alameda             15
# 1     244166      715  Alameda             15
# 2     202378      820  Alameda             17
# 3    2004420     1401   Sonoma             31
# 4     340332      763  Alameda             16

# %%
np_runId = 'PBA50Plus_NoProject_v37'
fbp_runid = 'PBA50Plus_Final_Blueprint_v65'

blg_2020_NP = pd.read_csv(
    r"M:\urban_modeling\baus\PBA50Plus\PBA50Plus_NoProject\{}\core_summaries\{}_building_summary_2020.csv".format(np_runId, np_runId),
    usecols=["parcel_id", 'year_built', 'non_residential_sqft', 'residential_units', 'building_type'],
    dtype={"parcel_id": int}
)
blg_2025_NP = pd.read_csv(
    r"M:\urban_modeling\baus\PBA50Plus\PBA50Plus_NoProject\{}\core_summaries\{}_building_summary_2025.csv".format(np_runId, np_runId),
    usecols=["parcel_id", 'year_built', 'non_residential_sqft', 'residential_units', 'building_type'],
    dtype={"parcel_id": int}
)
blg_2050_FBP = pd.read_csv(
    r"M:\urban_modeling\baus\PBA50Plus\PBA50Plus_FinalBlueprint\{}\core_summaries\{}_building_summary_2050.csv".format(fbp_runid, fbp_runid),
    usecols=["parcel_id", 'year_built', 'non_residential_sqft', 'residential_units', 'building_type'],
    dtype={"parcel_id": int}
)

# %%
building_type_dict = {
    'HS': 'single-family',
    'HT': 'single-family',
    'HM': 'multi-family',
    'MR': 'multi-family',
    'OF': 'office',
    'ME': 'office', 
    'RS': 'retail', 
    'RB': 'retail',
    'MT': 'retail',
    'IW': 'industrial',
    'IL': 'industrial',
    'IH': 'industrial',
    'PA2': 'parking',
    'SC': 'school',
    'HO': 'hotel',
}

def tally_blg_by_type_cnty_dist(buildings, cnty_sd_crosswalk, building_type_dict):
    # 
    buildings_CntySD = pd.merge(
        left     = buildings,
        right    = cnty_sd_crosswalk,
        on       = 'parcel_id',
        how      = 'left',
        validate = 'many_to_one'
    )
    # summary
    buildings_CntySD['building_cat'] = buildings_CntySD['building_type'].map(building_type_dict)
    blgs_by_cnty_type = buildings_CntySD.groupby(
        ['county', 'superdistrict', 'building_cat'])[['residential_units', 'non_residential_sqft']].sum()
    blgs_by_cnty_type.reset_index(inplace=True)
    return blgs_by_cnty_type

# %%
NP_2020_blgs_by_cnty_type = tally_blg_by_type_cnty_dist(blg_2020_NP, parcel_taz_sd_crosswalk_df, building_type_dict)
print(len(NP_2020_blgs_by_cnty_type))
NP_2025_blgs_by_cnty_type = tally_blg_by_type_cnty_dist(blg_2025_NP, parcel_taz_sd_crosswalk_df, building_type_dict)
print(len(NP_2025_blgs_by_cnty_type))
FBP_2050_blgs_by_cnty_type = tally_blg_by_type_cnty_dist(blg_2050_FBP, parcel_taz_sd_crosswalk_df, building_type_dict)
print(len(FBP_2050_blgs_by_cnty_type))
# Out:
# 299
# 299
# 300

# %%
NP_baseyear_blgs_by_cnty_type = pd.merge(
    NP_2020_blgs_by_cnty_type,
    NP_2025_blgs_by_cnty_type,
    on = ['county', 'superdistrict', 'building_cat'],
    how= 'outer',
    suffixes=('_2020', '_2025')
)
print(len(NP_baseyear_blgs_by_cnty_type))

NP_baseyear_blgs_by_cnty_type['residential_units_2023'] = \
    NP_baseyear_blgs_by_cnty_type['residential_units_2020'] + \
        ((2023-2020) / (2025-2020)) * (
            NP_baseyear_blgs_by_cnty_type['residential_units_2025'] - NP_baseyear_blgs_by_cnty_type['residential_units_2020'])
NP_baseyear_blgs_by_cnty_type['non_residential_sqft_2023'] = \
    NP_baseyear_blgs_by_cnty_type['non_residential_sqft_2020'] + \
        ((2023-2020) / (2025-2020)) * (
            NP_baseyear_blgs_by_cnty_type['non_residential_sqft_2025'] - NP_baseyear_blgs_by_cnty_type['non_residential_sqft_2020'])
display(NP_baseyear_blgs_by_cnty_type)
# Out:
# 299
#       county  superdistrict   building_cat  residential_units_2020  \
# 0    Alameda            9.0  single-family                    64.0
# 1    Alameda           12.0   multi-family                     5.0
# 2    Alameda           15.0          hotel                     0.0
# 3    Alameda           15.0     industrial                    54.0
# 4    Alameda           15.0   multi-family                 17449.0
# ..       ...            ...            ...                     ...
# 294   Sonoma           31.0   multi-family                  5729.0
# 295   Sonoma           31.0         office                    35.0
# 296   Sonoma           31.0         retail                    11.0
# 297   Sonoma           31.0         school                     0.0
# 298   Sonoma           31.0  single-family                 34545.0
#
#      non_residential_sqft_2020  residential_units_2025  \
# 0                          0.0                    64.0
# ...

# %%
blgs_by_cnty_type = pd.merge(
    NP_baseyear_blgs_by_cnty_type,
    FBP_2050_blgs_by_cnty_type.rename(
        columns={
            'residential_units': 'residential_units_2050',
            'non_residential_sqft': 'non_residential_sqft_2050'
        }
    ),
    on = ['county', 'superdistrict', 'building_cat'],
    how= 'outer',
)
print(len(blgs_by_cnty_type))
# Out:
# 300

# %%
for col in list(blgs_by_cnty_type):
    if col not in ['county', 'superdistrict', 'building_cat']:
        blgs_by_cnty_type[col] = blgs_by_cnty_type[col].fillna(0)
blgs_by_cnty_type['resUnits_growth'] = blgs_by_cnty_type['residential_units_2050'] - blgs_by_cnty_type['residential_units_2023']
blgs_by_cnty_type['nonResSQFT_growth'] = blgs_by_cnty_type['non_residential_sqft_2050'] - blgs_by_cnty_type['non_residential_sqft_2023']
blgs_by_cnty_type
# Out:
#             county  superdistrict   building_cat  residential_units_2020  \
# 0          Alameda            9.0  single-family                    64.0
# 1          Alameda           12.0   multi-family                     5.0
# 2          Alameda           15.0          hotel                     0.0
# 3          Alameda           15.0     industrial                    54.0
# 4          Alameda           15.0   multi-family                 17449.0
# ..             ...            ...            ...                     ...
# 295         Sonoma           31.0         office                    35.0
# 296         Sonoma           31.0         retail                    11.0
# 297         Sonoma           31.0         school                     0.0
# 298         Sonoma           31.0  single-family                 34545.0
# 299  San Francisco            5.0         retail                     0.0
#
#      non_residential_sqft_2020  residential_units_2025  \
# ...

# %%
blgs_by_cnty_type.groupby(['county','building_cat'])[['resUnits_growth', 'nonResSQFT_growth']].sum().reset_index()
# Out:
#      county   building_cat  resUnits_growth  nonResSQFT_growth
# 0   Alameda          hotel              0.0      -6.540660e+04
# 1   Alameda     industrial             -2.0      -4.575307e+06
# 2   Alameda   multi-family         215820.4      -5.971164e+06
# 3   Alameda         office              0.0      -6.961256e+06
# 4   Alameda        parking           -962.6       0.000000e+00
# ..      ...            ...              ...                ...
# 65   Sonoma         office              0.0      -4.225902e+05
# 66   Sonoma        parking              0.0       0.000000e+00
# 67   Sonoma         retail              0.0       1.833647e+04
# 68   Sonoma         school              0.0       0.000000e+00
# 69   Sonoma  single-family           3308.0      -4.758800e+03
#
# [70 rows x 4 columns]

# %%
# blgs_by_cnty_type.to_csv(r"C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\res_nonres_growth_by_cnty_type_FBP.csv", index=False)

# %% [markdown]
# ### investigate

# %%
# get 'p10_parcels_topo_fix' which is p10 with geometries fixed
p10_dataset_path = r'C:\Users\ywang\Documents\ArcGIS\Projects\PBA2050 Plus Blueprint Data QAQC - 20231206\PBA2050 Plus Blueprint Data QAQC.gdb'
print(p10_dataset_path)
p10_layers = fiona.listlayers(p10_dataset_path)
print(p10_layers)
p10_topo_fix = gpd.read_file(p10_dataset_path, driver='fileGDB', layer='p10_parcels_topo_fix')
print(p10_topo_fix.shape[0])
print(p10_topo_fix['parcel_id'].nunique())

print(p10_topo_fix.crs)
# Out:
# C:\Users\ywang\Documents\ArcGIS\Projects\PBA2050 Plus Blueprint Data QAQC - 20231206\PBA2050 Plus Blueprint Data QAQC.gdb
# ['p10_parcels_raw', 'p10_parcels_topo_fix', 'p10_urbansim_plan_geographies']
# 1956207
# 1956207
# epsg:26910

# %%
p10_topo_fix.head()
# Out:
#    parcel_id       county                jurisdiction       acres           x  \
# 0  1906302.0       Sonoma       unincorporated_sonoma  511.798014 -122.817466
# 1  1740249.0       Solano       unincorporated_solano  511.506506 -121.800569
# 2  1630642.0  Santa Clara  unincorporated_santa_clara  511.257790 -121.673229
# 3  1725445.0  Santa Clara  unincorporated_santa_clara  511.214820 -121.536227
# 4   837988.0        Marin        unincorporated_marin  511.124760 -122.586722
#
#            y  is_multipolygon  Shape_Length    Shape_Area  \
# 0  38.335496              0.0   6161.217358  2.071176e+06
# 1  38.146365              0.0   6556.948411  2.069997e+06
# 2  37.338219              0.0   8744.383142  2.068990e+06
# 3  37.111428              0.0   6188.698951  2.068816e+06
# 4  37.960474              0.0   8443.478588  2.068452e+06
#
#                                             geometry
# 0  MULTIPOLYGON Z (((515926.690 4244141.416 0.000...
# ...

# %%
blg_2020_NP_raw = pd.read_csv(
    r"M:\urban_modeling\baus\PBA50Plus\PBA50Plus_NoProject\{}\core_summaries\{}_building_summary_2020.csv".format(np_runId, np_runId),
    dtype={"parcel_id": int}
)

# %% [markdown]
# #### building type  = "PA2" with residential units > 0

# %%
# building type  = "PA2" with residential units > 0

print(blg_2020_NP.loc[(blg_2020_NP['building_type'] == 'PA2') & (blg_2020_NP['residential_units'] > 0)][['residential_units','non_residential_sqft']].sum())

print(blg_2020_NP.loc[(blg_2020_NP['building_type'] == 'PA2') & (blg_2020_NP['residential_units'] > 0)]['residential_units'].value_counts(dropna=False))

# looks like these are all from the 2010 base year data
blg_2020_NP_raw.loc[
    (blg_2020_NP_raw['building_type'] == 'PA2') & (blg_2020_NP_raw['residential_units'] > 0)].groupby(['source'])['residential_units'].sum().reset_index()
# Out:
# residential_units       36782.0
# non_residential_sqft        0.0
# dtype: float64
# residential_units
# 1.0      3041
# 2.0       514
# 4.0       305
# 3.0       292
# 5.0       160
#          ...
# 82.0        1
# 126.0       1
# 68.0        1
# 109.0       1
# 84.0        1
# Name: count, Length: 125, dtype: int64
#       source  residential_units
# 0  h5_inputs            36782.0

# %%
# write out shapefiles to check the locations of these buildings
blg_2020_NP_PA2 = pd.merge(
    left     = blg_2020_NP_raw.loc[(blg_2020_NP_raw['building_type'] == 'PA2') & (blg_2020_NP_raw['residential_units'] > 0)],
    right    = p10_topo_fix,
    on       = 'parcel_id',
    how      = 'left',
    validate = 'many_to_one'
)
blg_2020_NP_PA2 = blg_2020_NP_PA2.loc[blg_2020_NP_PA2['building_type'].notnull()]
blg_2020_NP_PA2 = gpd.GeoDataFrame(blg_2020_NP_PA2, geometry='geometry', crs=p10_topo_fix.crs)
print(len(blg_2020_NP_PA2))
# print(type(blg_2020_NP_PA2))
blg_2020_NP_PA2.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_PA2.shp')
# Out:
# 5514
# C:\Users\ywang\AppData\Local\Temp\ipykernel_21252\4161094772.py:13: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   blg_2020_NP_PA2.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_PA2.shp')

# %% [markdown]
# #### building_type in ['RS', 'RB', 'MT'] with residential units > 0

# %%
# building_type in ['RS', 'RB', 'MT'] with residential units > 0

print(blg_2020_NP.loc[(blg_2020_NP['building_type'].isin(['RS', 'RB', 'MT'])) & (blg_2020_NP['residential_units'] > 0)][['residential_units','non_residential_sqft']].sum())

print(blg_2020_NP.loc[(blg_2020_NP['building_type'].isin(['RS', 'RB', 'MT'])) & (blg_2020_NP['residential_units'] > 0)]['residential_units'].value_counts(dropna=False))

# check source
blg_2020_NP_raw.loc[
    (blg_2020_NP_raw['building_type'].isin(['RS', 'RB', 'MT'])) & (blg_2020_NP_raw['residential_units'] > 0)].groupby(['source'])['residential_units'].sum().reset_index()
# Out:
# residential_units           2284.0
# non_residential_sqft    16005800.0
# dtype: float64
# residential_units
# 1.0      493
# 2.0       15
# 4.0       11
# 3.0        8
# 8.0        7
# 6.0        7
# 10.0       5
# 5.0        5
# 7.0        4
# 22.0       4
# 19.0       3
# 9.0        3
# 15.0       3
# 20.0       3
# 16.0       2
# 12.0       2
# 14.0       2
# 32.0       2
# 35.0       2
# 11.0       2
# 40.0       1
# 25.0       1
# 122.0      1
# 144.0      1
# 27.0       1
# 39.0       1
# 71.0       1
# 47.0       1
# 45.0       1
# 54.0       1
# 26.0       1
# 24.0       1
# 72.0       1
# 34.0       1
# 70.0       1
# 64.0       1
# 42.0       1
# 29.0       1
# Name: count, dtype: int64
#               source  residential_units
# 0  basis_buildingsv0              487.0
# 1          h5_inputs             1797.0

# %% [markdown]
# #### building_type in ['HS', 'HT'] with non_residential_sqft > 0

# %%
# building_type in ['HS', 'HT'] with non_residential_sqft > 0

print(blg_2020_NP.loc[(blg_2020_NP['building_type'].isin(['HS', 'HT'])) & (blg_2020_NP['non_residential_sqft'] > 0)][['residential_units','non_residential_sqft']].sum())

print(blg_2020_NP_raw.loc[
    (blg_2020_NP_raw['building_type'].isin(['HS', 'HT'])) & (blg_2020_NP_raw['non_residential_sqft'] > 0)].groupby(['source'])['non_residential_sqft'].sum().reset_index())

# write out to check on a map
blg_2020_NP_HSHT = pd.merge(
    left     = blg_2020_NP_raw.loc[(blg_2020_NP_raw['building_type'].isin(['HS', 'HT'])) & (blg_2020_NP_raw['non_residential_sqft'] > 0)],
    right    = p10_topo_fix,
    on       = 'parcel_id',
    how      = 'left',
    validate = 'many_to_one'
)
blg_2020_NP_HSHT = blg_2020_NP_HSHT.loc[blg_2020_NP_HSHT['building_type'].notnull()]
blg_2020_NP_HSHT = gpd.GeoDataFrame(blg_2020_NP_HSHT, geometry='geometry', crs=p10_topo_fix.crs)
print(len(blg_2020_NP_HSHT))
# print(type(blg_2020_NP_HSHT))
blg_2020_NP_HSHT.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_HSHT.shp')
# Out:
# residential_units           6772.0
# non_residential_sqft    73729244.0
# dtype: float64
#               source  non_residential_sqft
# 0  basis_buildingsv0              358831.0
# 1          h5_inputs            73363922.0
# 2             manual                6491.0
# 19353
# C:\Users\ywang\AppData\Local\Temp\ipykernel_21252\2164826823.py:20: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   blg_2020_NP_HSHT.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_HSHT.shp')

# %% [markdown]
# #### building_type in ['HM'] with non_residential_sqft > 0

# %%
# building_type in ['HM'] with non_residential_sqft > 0

print(blg_2020_NP.loc[(blg_2020_NP['building_type'].isin(['HM'])) & (blg_2020_NP['non_residential_sqft'] > 0)][['residential_units','non_residential_sqft']].sum())

print(blg_2020_NP_raw.loc[
    (blg_2020_NP_raw['building_type'].isin(['HM'])) & (blg_2020_NP_raw['non_residential_sqft'] > 0)].groupby(['source'])['non_residential_sqft'].sum().reset_index())

# write out to check on a map
blg_2020_NP_HM = pd.merge(
    left     = blg_2020_NP_raw.loc[(blg_2020_NP_raw['building_type'].isin(['HM'])) & (blg_2020_NP_raw['non_residential_sqft'] > 0)],
    right    = p10_topo_fix,
    on       = 'parcel_id',
    how      = 'left',
    validate = 'many_to_one'
)
blg_2020_NP_HM = blg_2020_NP_HM.loc[blg_2020_NP_HM['building_type'].notnull()]
blg_2020_NP_HM = gpd.GeoDataFrame(blg_2020_NP_HM, geometry='geometry', crs=p10_topo_fix.crs)
print(len(blg_2020_NP_HM))
# print(type(blg_2020_NP_HM))
blg_2020_NP_HM.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_HM.shp')
# Out:
# residential_units          49120.0
# non_residential_sqft    55681423.0
# dtype: float64
#               source  non_residential_sqft
# 0         bas_bp_new              505407.0
# 1              basis               20000.0
# 2  basis_buildingsv0             3487916.0
# 3                 cs               67128.0
# 4          h5_inputs            51555322.0
# 5             manual               45650.0
# 5103
# C:\Users\ywang\AppData\Local\Temp\ipykernel_21252\3246116831.py:20: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   blg_2020_NP_HM.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_HM.shp')

# %% [markdown]
# #### building_type in ['MR'] with non_residential_sqft > 0

# %%
# building_type in ['MR'] with non_residential_sqft > 0

print(blg_2020_NP.loc[(blg_2020_NP['building_type'].isin(['MR'])) & (blg_2020_NP['non_residential_sqft'] > 0)][['residential_units','non_residential_sqft']].sum())

print(blg_2020_NP_raw.loc[
    (blg_2020_NP_raw['building_type'].isin(['MR'])) & (blg_2020_NP_raw['non_residential_sqft'] > 0)].groupby(['source'])['non_residential_sqft'].sum().reset_index())

# write out to check on a map
blg_2020_NP_MR = pd.merge(
    left     = blg_2020_NP_raw.loc[(blg_2020_NP_raw['building_type'].isin(['MR'])) & (blg_2020_NP_raw['non_residential_sqft'] > 0)],
    right    = p10_topo_fix,
    on       = 'parcel_id',
    how      = 'left',
    validate = 'many_to_one'
)
blg_2020_NP_MR = blg_2020_NP_MR.loc[blg_2020_NP_MR['building_type'].notnull()]
blg_2020_NP_MR = gpd.GeoDataFrame(blg_2020_NP_MR, geometry='geometry', crs=p10_topo_fix.crs)
print(len(blg_2020_NP_MR))
# print(type(blg_2020_NP_MR))
blg_2020_NP_MR.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_MR.shp')
# Out:
# residential_units          46157.0
# non_residential_sqft    86326121.0
# dtype: float64
#               source  non_residential_sqft
# 0         bas_bp_new              420914.0
# 1              basis              283759.0
# 2  basis_buildingsv0                4144.0
# 3          h5_inputs            85279629.0
# 4             manual              337675.0
# 7376
# C:\Users\ywang\AppData\Local\Temp\ipykernel_21252\3114197701.py:20: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   blg_2020_NP_MR.to_file(r'C:\Users\ywang\Box\Plan Bay Area 2050+\Performance and Equity\Plan Performance\Equity_Performance_Metrics\Final_Blueprint\other_metrics\blg_2020_NP_MR.shp')
